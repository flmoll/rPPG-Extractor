# %%
# %matplotlib inline
# !pip install ipywidgets==7.7.5
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ipywidgets==7.7.5 in /home/vscode/.local/lib/python3.12/site-packages (7.7.5)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/vscode/.local/lib/python3.12/site-packages (from ipywidgets==7.7.5) (6.29.5)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /home/vscode/.local/lib/python3.12/site-packages (from ipywidgets==7.7.5) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/vscode/.local/lib/python3.12/site-packages (from ipywidgets==7.7.5) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=3.6.4 in /home/vscode/.local/lib/python3.12/site-packages (from ipywidgets==7.7.5) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /home/vscode/.local/lib/python3.12/site-packages (from ipywidgets==7.7.5) (9.4.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in /home/vscode/.local/lib/python3.12/site-packages (from ipywidgets==7.7.5) (1.1.11)
# Requirement already satisfied: comm>=0.1.1 in /home/vscode/.local/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.5) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/vscode/.local/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.5) (1.8.14)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/vscode/.local/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.5) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/vscode/.local/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.5) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/vscode/.local/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.5) (0.1.7)
# Requirement already satisfied: nest-asyncio in /home/vscode/.local/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.5) (1.6.0)
# Requirement already satisfied: packaging in /home/vscode/.local/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.5) (24.2)
# Requirement already satisfied: psutil in /home/vscode/.local/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.5) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in /home/vscode/.local/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.5) (27.0.0)
# Requirement already satisfied: tornado>=6.1 in /home/vscode/.local/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.5) (6.5.1)
# Requirement already satisfied: decorator in /home/vscode/.local/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets==7.7.5) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /home/vscode/.local/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets==7.7.5) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/vscode/.local/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets==7.7.5) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /home/vscode/.local/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets==7.7.5) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/vscode/.local/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets==7.7.5) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /home/vscode/.local/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets==7.7.5) (2.19.1)
# Requirement already satisfied: stack_data in /home/vscode/.local/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets==7.7.5) (0.6.3)
# Requirement already satisfied: notebook>=4.4.1 in /home/vscode/.local/lib/python3.12/site-packages (from widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (7.4.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/vscode/.local/lib/python3.12/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets==7.7.5) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vscode/.local/lib/python3.12/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==7.7.5) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /home/vscode/.local/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets==7.7.5) (4.3.7)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/vscode/.local/lib/python3.12/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (2.16.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /home/vscode/.local/lib/python3.12/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (2.27.3)
# Requirement already satisfied: jupyterlab<4.5,>=4.4.4 in /home/vscode/.local/lib/python3.12/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (4.4.4)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /home/vscode/.local/lib/python3.12/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (0.2.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/vscode/.local/lib/python3.12/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets==7.7.5) (0.7.0)
# Requirement already satisfied: wcwidth in /home/vscode/.local/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets==7.7.5) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/vscode/.local/lib/python3.12/site-packages (from stack_data->ipython>=4.0.0->ipywidgets==7.7.5) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/vscode/.local/lib/python3.12/site-packages (from stack_data->ipython>=4.0.0->ipywidgets==7.7.5) (3.0.0)
# Requirement already satisfied: pure-eval in /home/vscode/.local/lib/python3.12/site-packages (from stack_data->ipython>=4.0.0->ipywidgets==7.7.5) (0.2.3)
# Requirement already satisfied: anyio>=3.1.0 in /home/vscode/.local/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/vscode/.local/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (25.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in /home/vscode/.local/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (3.1.5)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/vscode/.local/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/vscode/.local/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /home/vscode/.local/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in /home/vscode/.local/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /home/vscode/.local/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/vscode/.local/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (0.22.1)
# Requirement already satisfied: send2trash>=1.8.2 in /home/vscode/.local/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/vscode/.local/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/vscode/.local/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /home/vscode/.local/lib/python3.12/site-packages (from jupyterlab<4.5,>=4.4.4->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (2.0.5)
# Requirement already satisfied: httpx>=0.25.0 in /home/vscode/.local/lib/python3.12/site-packages (from jupyterlab<4.5,>=4.4.4->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/vscode/.local/lib/python3.12/site-packages (from jupyterlab<4.5,>=4.4.4->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (2.2.5)
# Requirement already satisfied: setuptools>=41.1.0 in /home/vscode/.local/lib/python3.12/site-packages (from jupyterlab<4.5,>=4.4.4->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (69.0.3)
# Requirement already satisfied: babel>=2.10 in /home/vscode/.local/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /home/vscode/.local/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (0.12.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/vscode/.local/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (4.24.0)
# Requirement already satisfied: requests>=2.31 in /home/vscode/.local/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (2.32.3)
# Requirement already satisfied: six>=1.5 in /home/vscode/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==7.7.5) (1.17.0)
# Requirement already satisfied: idna>=2.8 in /home/vscode/.local/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /home/vscode/.local/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in /home/vscode/.local/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (4.12.2)
# Requirement already satisfied: argon2-cffi-bindings in /home/vscode/.local/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (21.2.0)
# Requirement already satisfied: certifi in /home/vscode/.local/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab<4.5,>=4.4.4->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /home/vscode/.local/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab<4.5,>=4.4.4->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/vscode/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.5,>=4.4.4->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/vscode/.local/lib/python3.12/site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /home/vscode/.local/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/vscode/.local/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/vscode/.local/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/vscode/.local/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (0.26.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/vscode/.local/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in /home/vscode/.local/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /home/vscode/.local/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/vscode/.local/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /home/vscode/.local/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in /home/vscode/.local/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (6.2.0)
# Requirement already satisfied: defusedxml in /home/vscode/.local/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/vscode/.local/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/vscode/.local/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /home/vscode/.local/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/vscode/.local/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/vscode/.local/lib/python3.12/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (2.21.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/vscode/.local/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vscode/.local/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (2.3.0)
# Requirement already satisfied: webencodings in /home/vscode/.local/lib/python3.12/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /home/vscode/.local/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (1.4.0)
# Requirement already satisfied: fqdn in /home/vscode/.local/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (1.5.1)
# Requirement already satisfied: isoduration in /home/vscode/.local/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/vscode/.local/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (3.0.0)
# Requirement already satisfied: uri-template in /home/vscode/.local/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/vscode/.local/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in /home/vscode/.local/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /home/vscode/.local/lib/python3.12/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (2.7)
# Requirement already satisfied: pycparser in /home/vscode/.local/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /home/vscode/.local/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/vscode/.local/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets==7.7.5) (2.9.0.20250516)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import cv2
import re
import warnings
from scipy.sparse import spdiags
from scipy import signal
from scipy.signal import butter
import scipy
from tqdm import tqdm

# Try importing ipywidgets
try:
    import ipywidgets as widgets
    from IPython.display import display, clear_output
except ImportError as e:
    widgets = None
    print("ipywidgets is not available in this environment. Interactive features will be disabled.")

# %%
# !which python

import ipywidgets
print(ipywidgets.__version__)
# Out:
# /usr/local/bin/python
# 7.7.5

# %%
def load_tensor(filename):
    if filename.endswith('.npy'):
        tensor = np.load(filename)
    elif filename.endswith('.npz'):
        tensor = np.load(filename)['array1']

    return tensor

class Visualizer:
    def __init__(self, preprocessed_dataset_path, input_files, label_files):
        self.input_files = sorted(input_files)
        self.label_files = sorted(label_files)
        self.chunk_dropdown = None
        self.fig = None
        self.ax = None
        self.frame_index_slider = None
        self.current_chunk_index = 0
        self.current_frame_index = 0
        self.dataset_path = preprocessed_dataset_path
        self.avg_heart_rate = None

        self.diff_flag = "DiffNormalized" in preprocessed_dataset_path

        # Only initialize widgets if the library is available
        if widgets:
            self.create_visualization()
        else:
            print("Running in a non-widget environment. Visualization will be non-interactive.")

    def create_visualization(self):
        self.create_dropdown()
        self.create_figure()
        self.create_slider()
        self.create_frame_jump_button()

    def create_frame_jump_button(self):
        if widgets:
            self.frame_jump_button = widgets.Button(description='Jump one Frame')
            self.frame_jump_button.on_click(self.jump_one_frame)
            display(self.frame_jump_button)
        else:
            print("Button cannot be displayed: ipywidgets not available.")

    def create_dropdown(self):
        # Check if widgets are available
        if widgets:
            self.chunk_dropdown = widgets.Dropdown(
                options=self.input_files,
                description='Chunk:',
                layout=widgets.Layout(width='800px'),
                value=None
            )
            self.chunk_dropdown.observe(self.chunk_selection_changed, names='value')

            display(self.chunk_dropdown)
        else:
            print("Dropdown cannot be displayed: ipywidgets not available.")

    def create_figure(self):
        self.fig, self.ax = plt.subplots(figsize=(8, 4))
        self.ax.set_xticks([])
        self.ax.set_yticks([])
        plt.tight_layout()

    def create_slider(self):
        if widgets:
            num_frames = self.get_num_frames()
            self.frame_index_slider = widgets.IntSlider(
                min=0,
                max=num_frames - 1,
                step=1,
                value=0,
                description='Frame:',
                layout=widgets.Layout(width='800px')
            )
            self.frame_index_slider.observe(self.frame_index_changed, names='value')

            display(self.frame_index_slider)
        else:
            print("Slider cannot be displayed: ipywidgets not available.")

    def chunk_selection_changed(self, change):
        selected_chunk = change.new
        self.current_chunk_index = self.input_files.index(selected_chunk)
        self.current_frame_index = 0
        if self.frame_index_slider:
            self.frame_index_slider.value = 0
        self.update_frame()

    def frame_index_changed(self, change):
        self.current_frame_index = change.new
        self.update_frame()

    def jump_one_frame(self, change):
        if self.current_frame_index < self.get_num_frames() - 1:
            self.current_frame_index += 1
        else:
            print("Already at the last frame.")
            
        self.frame_index_slider.value = self.current_frame_index
        #self.update_frame()

    def get_num_frames(self):
        input_file = self.input_files[self.current_chunk_index]
        return load_tensor(os.path.join(self.dataset_path, input_file)).shape[0]

    def load_frame(self):
        input_file = self.input_files[self.current_chunk_index]
        input_data = load_tensor(os.path.join(self.dataset_path, input_file))
        print(f'The shape of the loaded chunk is {np.shape(input_data)}.')

        if input_data.shape[-1] == 6:
            rgb_frames = input_data[..., 3:]
            diff_normalized_frames = input_data[..., :3]

            # Create a side-by-side visualization
            frame = np.concatenate((rgb_frames, diff_normalized_frames), axis=2)
        elif input_data.shape[-1] == 3:
            # Use RGB frames directly for visualization
            frame = input_data
        else:
            raise ValueError("Invalid input_data shape. Expected shape (..., 3) or (..., 6).")

        return frame[self.current_frame_index]

    def load_label_frame(self):
        """
        Load the corresponding label data for the currently selected chunk.
        This method assumes the labels are stored in .npy files and are aligned
        with the input files in the same folder.
        """
        label_file = self.label_files[self.current_chunk_index]
        label_data = load_tensor(os.path.join(self.dataset_path, label_file))
        print(f'The shape of the loaded label file is {np.shape(label_data)}.')

        # Process the signal as needed (e.g., detrending, filtering)
        label_data = self._process_signal(label_data)

        return label_data

    def _process_signal(self, signal):
        """
        A helper function to process the signal (e.g., detrend and filter the PPG signal).
        You can adapt this based on your signal processing needs.
        """
        fs = 30  # Sampling frequency
        use_bandpass = True

        # Detrend signal or its cumulative sum based on diff_flag
        if self.diff_flag:
            # If the predictions and labels are the 1st derivative of the PPG signal
            detrended_signal = self._detrend(np.cumsum(signal), 100)
        else:
            # Detrend the original signal
            detrended_signal = self._detrend(signal, 100)

        # Apply bandpass filter if needed
        if use_bandpass:
            # Bandpass filter between [0.75, 2.5] Hz (45-150 bpm)
            b, a = butter(1, [0.75 / fs * 2, 2.5 / fs * 2], btype='bandpass')
            filtered_signal = scipy.signal.filtfilt(b, a, np.double(detrended_signal))
            return filtered_signal

        return detrended_signal

    def _detrend(self, input_signal, lambda_value):
        """
        Detrend the input signal.
        This method removes long-term trends from the signal using a smoothing filter.
        """
        signal_length = input_signal.shape[0]
        H = np.identity(signal_length)
        ones = np.ones(signal_length)
        minus_twos = -2 * np.ones(signal_length)
        diags_data = np.array([ones, minus_twos, ones])
        diags_index = np.array([0, 1, 2])
        D = spdiags(diags_data, diags_index, signal_length - 2, signal_length).toarray()

        # Apply smoothing
        detrended_signal = np.dot(
            (H - np.linalg.inv(H + (lambda_value ** 2) * np.dot(D.T, D))), input_signal
        )
        return detrended_signal

    def create_label_figure(self):
        # Create figure with two subplots: time-domain and frequency-domain
        self.label_fig, (self.label_ax_time, self.label_ax_fft) = plt.subplots(2, 1, figsize=(8, 6))
        self.label_ax_time.set_xlabel('Frame #')
        self.label_ax_time.set_ylabel('Magnitude')
        self.label_ax_fft.set_xlabel('Frequency')
        self.label_ax_fft.set_ylabel('Magnitude')

    def update_label_frame(self):
        def _next_power_of_2(x):
            """Calculate the nearest power of 2."""
            return 1 if x == 0 else 2 ** (x - 1).bit_length()

        clear_output(wait=True)

        label_frame = self.load_label_frame()

        # Zero-padding the signal to improve frequency resolution
        N = _next_power_of_2(label_frame.shape[0])
        fs = 30  # Sampling frequency
        ppg_label_fft = label_frame
        
        ppg_label_f, ppg_label_pxx = signal.periodogram(ppg_label_fft, fs=fs, nfft=N, detrend=False)

        # Find the frequency corresponding to the highest power within the heart rate range (0.75 - 2.5 Hz)
        heart_rate_range = (0.75, 2.5)
        idx = np.where((ppg_label_f >= heart_rate_range[0]) & (ppg_label_f <= heart_rate_range[1]))[0]
        dominant_frequency = ppg_label_f[idx[np.argmax(ppg_label_pxx[idx])]]
        self.avg_heart_rate = dominant_frequency * 60  # Convert Hz to bpm (beats per minute)

        # Clear the figure to prevent double visualization
        self.label_fig.clear()

        # Create the time-domain plot
        self.label_ax_time = self.label_fig.add_subplot(211)  # First subplot for time-domain
        self.label_ax_time.plot(label_frame)
        self.label_ax_time.set_xlabel('Frame #')
        self.label_ax_time.set_ylabel('Magnitude')

        # Create the frequency-domain plot
        self.label_ax_fft = self.label_fig.add_subplot(212)  # Second subplot for frequency-domain
        self.label_ax_fft.plot(ppg_label_f, ppg_label_pxx / ppg_label_pxx.max())
        self.label_ax_fft.set_xlabel('Frequency (Hz)')
        self.label_ax_fft.set_ylabel('Magnitude')
        self.label_ax_fft.set_xlim([0, 5])  # Limit the x-axis to relevant frequencies (0-5 Hz)

        self.label_fig.suptitle(self.label_files[self.current_chunk_index], y=1.02)
        self.label_fig.tight_layout()

        # Display the average heart rate as standalone text below the entire figure
        self.label_fig.text(0.5, -0.05, f'Average Heart Rate: {self.avg_heart_rate:.2f} bpm',
                            ha='center', va='center', fontsize=16, color='red', weight='bold')

    def update_frame(self):
        clear_output(wait=True)

        self.fig.clear()

        frame = self.load_frame()

        # Recreate the axes for the figure and draw the image
        self.ax = self.fig.add_subplot(111)
        self.ax.imshow(frame)

        self.ax.set_xticks([])
        self.ax.set_yticks([])

        self.ax.set_title(f"{self.input_files[self.current_chunk_index]} - Frame {self.current_frame_index}")

        self.fig.tight_layout()

        self.update_label_frame()

        display(self.chunk_dropdown, self.frame_index_slider, self.frame_jump_button, self.fig)

    def update_frame(self):
        clear_output(wait=True)

        self.fig.clear()  # This ensures the whole figure is cleared before re-drawing

        frame = self.load_frame()

        # Recreate the axes for the figure and draw the image
        self.ax = self.fig.add_subplot(111)
        self.ax.imshow(frame)

        self.ax.set_xticks([])
        self.ax.set_yticks([])

        self.ax.set_title(f"{self.input_files[self.current_chunk_index]} - Frame {self.current_frame_index}")

        self.fig.tight_layout()

        self.update_label_frame()

        display(self.chunk_dropdown, self.frame_index_slider, self.frame_jump_button, self.fig, self.label_fig)

# %%
# FILL THIS IN! This is the path to your preprocessed dataset folder.
preprocessed_dataset_path = "/mnt/results/preprocessed_rppgToolbox/emergency/Emergency_Videos_SizeW128_SizeH128_ClipLength160_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendMOSSE_Large_boxTrue_Large_size1.5_Dyamic_DetTrue_det_len1_Median_face_boxFalse_DDEEPSTAB_amp10.0V_10.0_9999.0"
compressed = False            

if compressed:
    regex = r".*input\d+\.npy.compressed.npz"
else:
    regex = r".*input\d+\.npy"

input_files = [filename for filename in os.listdir(preprocessed_dataset_path) if (filename.endswith(".npy") or filename.endswith(".npz")) and re.match(regex, filename)]
label_files = [input_file.replace("input", "label") for input_file in input_files if input_file.replace("input", "label") in os.listdir(preprocessed_dataset_path)]

if len(input_files) == 0 or len(label_files) == 0:
    print("Error: No valid input or label files found in the directory.")
else:
    print(f"{len(input_files)} input files and {len(label_files)} label files detected.")
# Out:
# 30 input files and 30 label files detected.

# %%
# Create the visualizer instance
visualizer = Visualizer(preprocessed_dataset_path, input_files, label_files)

# Create the label figure
visualizer.create_label_figure()
# Out:
# Dropdown(description='Chunk:', index=25, layout=Layout(width='800px'), options=('0_input0.npy.compressed.npz',…
# IntSlider(value=0, description='Frame:', layout=Layout(width='800px'), max=159)
# Button(description='Jump one Frame', style=ButtonStyle())
